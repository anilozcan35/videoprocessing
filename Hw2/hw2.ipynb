# %%
# !pip install kaggle

# %%
from google.colab import userdata
import os

os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# %%
# %cd /content/drive/MyDrive/Video Processing/Hw2
# Out:
# /content/drive/MyDrive/Video Processing/Hw2

# %%
# !mkdir data

# %%
# !ls
# Out:
# 235B7022_ararapor.pdf  235B7022_Proposal.pdf  Hw1  Hw2	README.md

# %%
# %cd /content/drive/MyDrive/Video Processing/Hw2/data
# Out:
# /content/drive/MyDrive/Video Processing/Hw2/data

# %%
# !kaggle competitions download -c cifar-10
# Out:
# ...
#  99% 711M/715M [00:10<00:00, 72.9MB/s]
# 100% 715M/715M [00:10<00:00, 74.0MB/s]

# %%
! unzip "cifar-10.zip"
# Out:
# Archive:  cifar-10.zip
#   inflating: sampleSubmission.csv
#   inflating: test.7z
#   inflating: train.7z
#   inflating: trainLabels.csv

# %%
# !pip install pyunpack

# %%
# !pip install patool
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 2.7 MB/s eta 0:00:00
# ...

# %%
from pyunpack import Archive

# %%
# %cd /content/drive/MyDrive/Video Processing/Hw2/data
# Out:
# /content/drive/MyDrive/Video Processing/Hw2/data

# %%
# !pip install py7zr

# %%
import py7zr
for i in os.listdir():
  if i.endswith('.7z'):
      print(i)
# Out:
# test.7z
# train.7z

# %%
with py7zr.SevenZipFile("train.7z", mode='r') as z:
  z.extractall("/content/drive/MyDrive/Video Processing/Hw2/data")

# %%
with py7zr.SevenZipFile("test.7z", mode='r') as z:
  z.extractall("/content/drive/MyDrive/Video Processing/Hw2/data")

# %%
# !pip install bash_kernel

# %%
# %%writefile remove.sh
#
# cd /content/drive/MyDrive/Video\ Processing/Hw2/data
# rm train.7z test.7z trainLabels.csv sampleSubmission.csv cifar-10.zip
# Out:
# Writing remove.sh

# %%
# %%shell
#
# bash remove.sh

# %%
# !rm remove.sh

# %%
# %cd /content/drive/MyDrive/Video Processing
# Out:
# /content/drive/MyDrive/Video Processing

# %%
with open('.gitignore', 'w') as fp:
    pass
